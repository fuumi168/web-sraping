# %%
#from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.24h.com.vn/'

# %%
hdr = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Mobile Safari/537.36 Edg/116.0.1938.54'}
response = requests.get(url, headers=hdr)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="vi" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="vi" http-equiv="Content-Language">
# <link href="/favicon.gif" rel="icon" type="image/gif"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://icdn.24h.com.vn/" rel="dns-prefetch"/>
# <link href="https://anh.24h.com.vn/" rel="dns-prefetch"/>
# <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Bold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Italic.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Medium.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="vi" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="vi" http-equiv="Content-Language">
#    <link href="/favicon.gif" rel="icon" type="image/gif"/>
#    <meta content="on" http-equiv="x-dns-prefetch-control"/>
#    <link href="https://icdn.24h.com.vn/" rel="dns-prefetch"/>
#    <link href="https://anh.24h.com.vn/" rel="dns-prefetch"/>
#    <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Regular.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Bold.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Italic.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://cdn.24h.com.vn/css/fonts/Roboto-Medium.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
tags = soup.findAll("div", {"class": "md"})
tags
# Out:
# []

# %%
for mytag in tags:
  print(mytag.get_text())

# %%
data = requests.get(url).text
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# https://www.24h.com.vn/
# https://www.24h.com.vn/tin-tuc-trong-ngay-c46.html
# https://www.24h.com.vn/bong-da-c48.html
# https://www.24h.com.vn/cang-thang-iran-israel-c415e7805.html
# https://www.24h.com.vn/tin-moi-tong-hop-c1092.html
# https://www.24h.com.vn/tin-tuc-trong-ngay/tong-bi-thu-chu-tich-nuoc-to-lam-dut-khoat-tu-bo-tu-duy-khong-quan-duoc-thi-cam-c46a1612359.html
# https://www.24h.com.vn/tin-tuc-trong-ngay/tong-bi-thu-chu-tich-nuoc-to-lam-dut-khoat-tu-bo-tu-duy-khong-quan-duoc-thi-cam-c46a1612359.html
# https://www.24h.com.vn/tin-tuc-trong-ngay/tong-bi-thu-chu-tich-nuoc-to-lam-dut-khoat-tu-bo-tu-duy-khong-quan-duoc-thi-cam-c46a1612359.html
# https://www.24h.com.vn/tin-tuc-quoc-te/bao-my-ong-trump-co-co-hoi-thang-cu-vuot-xa-ba-harris-c415a1612410.html
# https://www.24h.com.vn/tin-tuc-quoc-te-c415.html
# https://www.24h.com.vn/tin-tuc-quoc-te/bao-my-ong-trump-co-co-hoi-thang-cu-vuot-xa-ba-harris-c415a1612410.html
# ...

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>
print(table)
# Out:
# None

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="" class="img-fluid img-scale-down d-block" src="https://icdn.24h.com.vn/images/2023/logo_24h_mobile_2.svg"/>
# https://icdn.24h.com.vn/images/2023/logo_24h_mobile_2.svg
# <img alt="#" class="icon-view img-fluid img-scale-down d-block mar-auto mar-b-5" src="https://icdn.24h.com.vn/upload/3-2021/images/2021-07-15/tintuc-1541387818-643-width20height18-1626315014-969-width20height18.png"/>
# https://icdn.24h.com.vn/upload/3-2021/images/2021-07-15/tintuc-1541387818-643-width20height18-1626315014-969-width20height18.png
# <img alt="#" class="icon-view img-fluid img-scale-down d-block mar-auto mar-b-5" src="https://icdn.24h.com.vn/upload/4-2021/images/2021-10-15/b--ng------1634260761-233-width20height20.png"/>
# https://icdn.24h.com.vn/upload/4-2021/images/2021-10-15/b--ng------1634260761-233-width20height20.png
# ...
